# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/connerkhudaverdyan/Downloads/estat_sts_trtu_m_filtered_en.csv")

# %%
pivot_df = df.pivot(index='geo', columns='TIME_PERIOD', values='OBS_VALUE')

pivot_df
# Out:
# TIME_PERIOD                                1991-01  1991-02  1991-03  1991-04  \
# geo
# Albania                                        NaN      NaN      NaN      NaN
# Austria                                        NaN      NaN      NaN      NaN
# Belgium                                        NaN      NaN      NaN      NaN
# Bosnia and Herzegovina                         NaN      NaN      NaN      NaN
# Bulgaria                                       NaN      NaN      NaN      NaN
# Croatia                                        NaN      NaN      NaN      NaN
# Cyprus                                         NaN      NaN      NaN      NaN
# Czechia                                        NaN      NaN      NaN      NaN
# Denmark                                        NaN      NaN      NaN      NaN
# Estonia                                        NaN      NaN      NaN      NaN
# Euro area - 19 countries  (2015-2022)          NaN      NaN      NaN      NaN
# ...

# %%
pivot_df.columns.get_loc('2000-01')
# Out:
# 108

# %%
retail_data = pivot_df.iloc[:,108:]
retail_data.to_excel('final_retail.xlsx')
